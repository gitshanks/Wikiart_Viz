# %%
import pandas as pd
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# !ls
# Out:
# Project 2.docx   WikiArtClean.csv fonts            js
# Project2.twb     css              images
# README.md        data_check.ipynb index.html

# %%
df = pd.read_csv("WikiArtClean.csv")

# %%
df.head()
# Out:
#              Style              Category         Artist  \
# 0  Renaissance Art  Northern Renaissance  Robert Campin
# 1  Renaissance Art     Early Renaissance       Masaccio
# 2  Renaissance Art  Northern Renaissance  Robert Campin
# 3  Renaissance Art     Early Renaissance       Masaccio
# 4  Renaissance Art     Early Renaissance       Masaccio
#
#                                                Title  Year  \
# 0  Triptych: The Two Thieves with the Empty Cross...  1415
# 1                               St. Juvenal Triptych  1422
# 2                 Blessing Christ and Praying Virgin  1424
# 3                                  The Tribute Money  1425
# 4                                           St. Paul  1426
#
#                                            Image URL  \
# 0  https://use2-uploads7.wikiart.org/images/rober...
# 1  https://use2-uploads3.wikiart.org/images/masac...
# 2  https://use2-uploads0.wikiart.org/images/rober...
# ...

# %%
list(df)
# Out:
# ['Style',
#  'Category',
#  'Artist',
#  'Title',
#  'Year',
#  'Image URL',
#  'Painting Info URL',
#  'Artist Info URL',
#  'Is painting',
#  'Face or body',
#  'Mean rating',
#  'Agreeableness',
#  'Anger',
#  'Anticipation',
#  'Arrogance',
#  'Disagreeableness',
#  'Disgust',
#  'Fear',
#  'Gratitude',
#  'Happiness',
#  'Humility',
#  'Love',
#  'Optimism',
#  'Pessimism',
#  'Regret',
#  'Sadness',
#  'Shame',
#  'Shyness',
#  'Surprise',
#  'Trust',
#  'Neutral']

# %%
df.describe()
# Out:
#               Year  Mean rating  Agreeableness        Anger  Anticipation  \
# count  3646.000000  3646.000000    3646.000000  3646.000000   3646.000000
# mean   1871.229018     0.840985       0.031383     0.034747      0.195254
# std     137.693102     0.854493       0.053155     0.076504      0.146399
# min    1415.000000    -2.000000       0.000000     0.000000      0.000000
# 25%    1840.000000     0.200000       0.000000     0.000000      0.091000
# 50%    1922.000000     0.900000       0.000000     0.000000      0.182000
# 75%    1961.000000     1.507500       0.074000     0.041000      0.300000
# max    2012.000000     2.800000       0.500000     0.800000      0.900000
#
#          Arrogance  Disagreeableness      Disgust         Fear    Gratitude  \
# count  3646.000000       3646.000000  3646.000000  3646.000000  3646.000000
# mean      0.047428          0.036377     0.078279     0.109433     0.052488
# ...

# %%
# list(df[df['Is painting'] == "no"]['Image URL'])

# %%
# df['Disagreeableness'].std()

# %%
# df.groupby(['Year']).agg(['count', 'mean', 'std'])

# %%
## over the year, category dist, or counts of pieces 
## within the year, show the mean values for the year 

## split the data into the paining or not?

## rating values for the year?

# %%
# df.groupby(['Year', 'Is painting']).count()

# %%
df[df['Is painting'] == "yes"].groupby(['Year'])["Style"].count().plot(kind='bar')

# %%
df[df['Is painting'] == "no"].groupby(['Year'])["Style"].count().plot(kind='bar')

# %%
# for img in list(df[df['Face or body'] == "none"]['Image URL']):

# %%
df.groupby(['Face or body', 'Style'])['Mean rating'].mean()
# Out:
# Face or body  Style
# body          Modern Art                         0.891645
#               Post Renaissance Art               1.595965
#               Renaissance Art                    1.021667
# face          Contemporary Art                   0.625000
#               Modern Art                         0.974685
#               Modern Art,Post Renaissance Art    1.300000
#               Post Renaissance Art               1.519561
#               Renaissance Art                    1.312071
# none          Contemporary Art                  -0.118877
#               Contemporary Art,Modern Art       -0.472857
#               Modern Art                         0.419015
#               Post Renaissance Art               1.526747
#               Renaissance Art                    0.690000
# Name: Mean rating, dtype: float64

# %%
len(df['Artist'].unique())
# Out:
# 986

# %%
df.groupby(['Artist'])['Style'].count().value_counts()
# Out:
# 1     220
# 2     180
# 3     148
# 4     124
# 5     117
# 6      83
# 7      38
# 8      26
# 10     19
# 9      13
# 11      4
# 14      4
# 12      2
# 13      2
# 20      1
# 15      1
# 16      1
# 17      1
# 19      1
# 25      1
# Name: Style, dtype: int64

# %%
from pandas.plotting import scatter_matrix

# %%
data = df[['Agreeableness',
 'Anger',
#  'Anticipation',
 'Arrogance',
#  'Disagreeableness',
 'Disgust',
 'Fear',
#  'Gratitude',
 'Happiness',
 'Humility',
 'Love',
 'Optimism',
#  'Pessimism',
 'Regret',
 'Sadness',
 'Shame',
#  'Shyness',
 'Surprise',
#  'Trust',
#  'Neutral'
          ]]

axes = scatter_matrix(data, alpha = 0.3, figsize = (14,8), diagonal = 'kde')
corr = data.corr().as_matrix()
for i, j in zip(*np.triu_indices_from(axes, k=1)):
    axes[i, j].annotate("%.5f" %corr[i,j], (0.8, 0.8), xycoords='axes fraction', ha='center', va='center')
# Out:
# /Users/telly/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:24: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.

# %%
# df['Happiness']

# %%
# years = df['Year'].unique()

# for year in years: 
    
#     print("<h1> year {} </h1>".format(year))
#     urls = list(df[df['Year'] == year]['Image URL'])
#     for url in urls: 
#         print("<img src=\"{}\" width=\"250\">".format(url))

# %%
# for l in list(df[df['Face or body'] == "none"]['Image URL']): 
#     print(l)

# %%
from scipy.stats.stats import pearsonr

# %%
list(df)
# Out:
# ['Style',
#  'Category',
#  'Artist',
#  'Title',
#  'Year',
#  'Image URL',
#  'Painting Info URL',
#  'Artist Info URL',
#  'Is painting',
#  'Face or body',
#  'Mean rating',
#  'Agreeableness',
#  'Anger',
#  'Anticipation',
#  'Arrogance',
#  'Disagreeableness',
#  'Disgust',
#  'Fear',
#  'Gratitude',
#  'Happiness',
#  'Humility',
#  'Love',
#  'Optimism',
#  'Pessimism',
#  'Regret',
#  'Sadness',
#  'Shame',
#  'Shyness',
#  'Surprise',
#  'Trust',
#  'Neutral']

# %%
sentiments = ['Agreeableness',
 'Anger',
 'Anticipation',
 'Arrogance',
 'Disagreeableness',
 'Disgust',
 'Fear',
 'Gratitude',
 'Happiness',
 'Humility',
 'Love',
 'Optimism',
 'Pessimism',
 'Regret',
 'Sadness',
 'Shame',
 'Shyness',
 'Surprise',
 'Trust',
 'Neutral']

# %%
for sentiment in sentiments:
    r = pearsonr(df[sentiment], df['Mean rating'])
    print(sentiment)
    print(r)
    print()
# Out:
# Agreeableness
# (0.18966968170017773, 7.066464743851956e-31)
#
# Anger
# (-0.16615648026573385, 5.540053352213746e-24)
#
# Anticipation
# (-0.3078591241109421, 6.919830789358902e-81)
#
# Arrogance
# (0.0663448442123497, 6.0954248214802356e-05)
#
# Disagreeableness
# (-0.20232577584192918, 5.481025200337058e-35)
#
# Disgust
# (-0.5203054236626968, 3.984943657351008e-252)
#
# Fear
# (-0.26076956336588497, 9.514573734199253e-58)
#
# Gratitude
# (0.36755506819191636, 5.1274010118603276e-117)
#
# Happiness
# (0.6476079003326238, 0.0)
#
# Humility
# (0.4553472259299828, 3.959496688215346e-186)
#
# Love
# (0.388437002401423, 1.287357106026197e-131)
#
# Optimism
# (0.4390443583217958, 1.0890234204317987e-171)
#
# Pessimism
# (-0.1986364600855534, 9.253332944439232e-34)
#
# Regret
# (-0.03301581733750069, 0.04621495466974519)
#
# Sadness
# (-0.00565289059493405, 0.7329385829576224)
#
# Shame
# (-0.11413359272568811, 4.783373595600082e-12)
#
# Shyness
# ...

# %%
help(pearsonr)
# Out:
# Help on function pearsonr in module scipy.stats.stats:
#
# pearsonr(x, y)
#     Pearson correlation coefficient and p-value for testing non-correlation.
#
#     The Pearson correlation coefficient [1]_ measures the linear relationship
#     between two datasets.  The calculation of the p-value relies on the
#     assumption that each dataset is normally distributed.  (See Kowalski [3]_
#     for a discussion of the effects of non-normality of the input on the
#     distribution of the correlation coefficient.)  Like other correlation
#     coefficients, this one varies between -1 and +1 with 0 implying no
#     correlation. Correlations of -1 or +1 imply an exact linear relationship.
#     Positive correlations imply that as x increases, so does y. Negative
#     correlations imply that as x increases, y decreases.
#
#     The p-value roughly indicates the probability of an uncorrelated system
#     producing datasets that have a Pearson correlation at least as extreme
# ...
